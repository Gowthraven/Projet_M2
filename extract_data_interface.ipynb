# %% [markdown]
# # Extraction des données

# %%
from extract_data import *

# %% [markdown]
# ## Extraction des fichiers xml
# Requirement : Les fichier xml

# %%
path_to_xml= "Data/data_xml"
file_output= "Data/data.json"
D= data_to_json(path_to_xml)
with open(file_output, 'w',encoding="utf-8") as f:
    json.dump(D,f,indent=2)
print(f'{file_output} with {len(D)} scores created.')
# Out:
# Data/data.json with 169 scores created.

# %% [markdown]
# ## Extraction des mélodies
# Requirement : Le fichier data.json

# %%
filename="dataset"
size_melody= 1000 #en mesure ( 1000 = max de la partie )
time_signatures=set(["2/4"]) #prend toutes les time signatures par default

n=json_into_melody("Data/data.json",output_file=filename,size=size_melody,time_signatures=time_signatures)
print(f"Toutes les melodies ({n}) ont étés générées.")

filename="dataset3"
size_melody= 3 #en mesure ( 1000 = max de la partie )
time_signatures=set(["2/4"]) #prend toutes les time signatures par default

parts_len=json_into_part_melody("Data/data.json",output_file=filename,size=size_melody,time_signatures=time_signatures)
print("Toutes les melodies ont étés générées par parties. Tailles des parties : "+" ".join([f"{key} : {length} " for key,length in parts_len]))
# Out:
# Toutes les melodies (407) ont étés générées.
# Toutes les melodies ont étés générées par parties. Tailles des parties : A : 2579  B : 2261  C : 1306  D : 20

# %% [markdown]
# ---

# %% [markdown]
# ###  Visualiser une partition

# %%
filename= "SÃO JOÃO DO SAPOTI.xml"
s=open_one_xml(path_to_xml,filename)
show_stat(s)
# Out:
# {0.0} <music21.text.TextBox 'São João d...'>
# {0.0} <music21.text.TextBox 'SIVUCA'>
# {0.0} <music21.text.TextBox 'Aldo Guina...'>
# {0.0} <music21.metadata.Metadata object at 0x1473c2f6e48>
# {0.0} <music21.stream.Part P1>
#     {0.0} <music21.instrument.Instrument 'P1: P1: '>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.expressions.TextExpression 'Baião'>
#         {0.0} <music21.layout.PageLayout>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.layout.StaffLayout distance None, staffNumber 1, staffSize None, staffLines None>
#         {0.0} <music21.clef.TrebleClef>
#         {0.0} <music21.key.Key of F major>
#         {0.0} <music21.meter.TimeSignature 2/4>
#         {0.0} <music21.note.Rest quarter>
#         {1.0} <music21.note.Rest 16th>
#         {1.25} <music21.repeat.Segno 'Segno'>
#         {1.25} <music21.note.Note A>
#         {1.5} <music21.note.Note D>
#         {1.75} <music21.note.Note E>
#     {0.0} <music21.spanner.RepeatBracket 1 <music21.stream.Measure 17 offset=32.0>>
#     {0.0} <music21.spanner.RepeatBracket 2 <music21.stream.Measure 18 offset=34.0>>
#     {0.0} <music21.spanner.RepeatBracket 1 <music21.stream.Measure 26 offset=175.0>>
#     {0.0} <music21.spanner.RepeatBracket 2 <music21.stream.Measure 27 offset=177.0>>
#     {2.0} <music21.stream.Measure 2 offset=2.0>
#         {0.0} <music21.expressions.RehearsalMark 'A'>
#         {0.0} <music21.bar.Repeat direction=start>
#         {0.0} <music21.note.Note F>
#         {0.25} <music21.note.Note E>
#         {0.5} <music21.harmony.ChordSymbol Dm7>
#         {0.5} <music21.note.Note D>
#         {0.75} <music21.note.Note C>
#         {1.0} <music21.note.Note B->
#         {1.25} <music21.note.Note A>
#         {1.5} <music21.note.Note G>
#         {1.75} <music21.note.Note A>
#     {4.0} <music21.stream.Measure 3 offset=4.0>
#         {0.0} <music21.harmony.ChordSymbol Gm7>
#         {0.0} <music21.note.Note B->
#         {0.25} <music21.note.Note B->
#         {0.5} <music21.note.Note D>
#         {0.75} <music21.note.Note B->
#         {1.0} <music21.note.Note G>
#         {1.25} <music21.note.Note F>
#         {1.5} <music21.note.Note E>
#     {6.0} <music21.stream.Measure 4 offset=6.0>
#         {0.0} <music21.harmony.ChordSymbol A7>
#         {0.0} <music21.note.Rest 16th>
#         {0.25} <music21.note.Note A>
#         {0.5} <music21.note.Note C#>
#         {0.75} <music21.note.Note E>
#         {1.0} <music21.note.Note G>
#         {1.25} <music21.note.Note A>
#         {1.5} <music21.note.Note B->
#         {1.75} <music21.note.Note G>
#     {8.0} <music21.stream.Measure 5 offset=8.0>
#         {0.0} <music21.harmony.ChordSymbol Dm>
#         {0.0} <music21.note.Note A>
#         {0.25} <music21.note.Note A>
#         {0.5} <music21.note.Note D>
#         {0.75} <music21.note.Note A>
#         {1.0} <music21.note.Note F>
#         {1.25} <music21.note.Note E>
#         {1.5} <music21.note.Note D>
#     {10.0} <music21.stream.Measure 6 offset=10.0>
#         {0.0} <music21.note.Rest 16th>
#         {0.25} <music21.harmony.ChordSymbol Dm7>
#         {0.25} <music21.note.Note A>
#         {0.5} <music21.note.Note D>
#         {0.75} <music21.note.Note E>
#         {1.0} <music21.note.Note F>
#         {1.25} <music21.note.Note G>
#         {1.5} <music21.note.Note A>
#         {1.75} <music21.note.Note F>
#     {12.0} <music21.stream.Measure 7 offset=12.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.layout.StaffLayout distance None, staffNumber 1, staffSize None, staffLines None>
#         {0.0} <music21.harmony.ChordSymbol Gm7>
#         {0.0} <music21.note.Note G>
#         {0.25} <music21.note.Note G>
#         {0.5} <music21.note.Note B->
#         {0.75} <music21.note.Note G>
#         {1.0} <music21.note.Note E>
#         {1.25} <music21.note.Note D>
#         {1.5} <music21.note.Note C#>
#     {14.0} <music21.stream.Measure 8 offset=14.0>
#         {0.0} <music21.harmony.ChordSymbol A7>
#         {0.0} <music21.note.Rest 16th>
#         {0.25} <music21.note.Note A>
#         {0.5} <music21.note.Note C#>
#         {0.75} <music21.note.Note E>
#         {1.0} <music21.note.Note G>
#         {1.25} <music21.note.Note G->
#         {1.5} <music21.note.Note F>
#         {1.75} <music21.note.Note E>
#     {16.0} <music21.stream.Measure 9 offset=16.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {0.25} <music21.note.Note D>
#             {0.5} <music21.note.Note F>
#             {0.75} <music21.note.Note A>
#             {1.0} <music21.note.Note D>
#             {1.25} <music21.note.Note F>
#             {1.5} <music21.note.Note A>
#             {1.75} <music21.note.Note D>
#         {0.0} <music21.stream.Voice 2>
#             {0.0} <music21.note.Note D>
#             {0.5} <music21.note.Rest eighth>
#             {1.0} <music21.note.Rest quarter>
#         {0.0} <music21.harmony.ChordSymbol Dm>
#     {18.0} <music21.stream.Measure 10 offset=18.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {0.25} <music21.note.Note E>
#             {0.5} <music21.note.Note D>
#             {0.75} <music21.note.Note C>
#             {1.0} <music21.note.Note B->
#             {1.25} <music21.note.Note A>
#             {1.5} <music21.note.Note G>
#             {1.75} <music21.note.Note A>
#         {0.0} <music21.stream.Voice 2>
#             {0.0} <music21.note.Note D>
#             {0.5} <music21.note.Rest eighth>
#             {1.0} <music21.note.Rest quarter>
#         {0.0} <music21.harmony.ChordSymbol Dm7>
#     {20.0} <music21.stream.Measure 11 offset=20.0>
#         {0.0} <music21.harmony.ChordSymbol Gm7>
#         {0.0} <music21.note.Note B->
#         {0.25} <music21.note.Note B->
#         {0.5} <music21.note.Note D>
#         {0.75} <music21.note.Note B->
#         {1.0} <music21.note.Note G>
#         {1.25} <music21.note.Note F>
#         {1.5} <music21.note.Note E>
#     {22.0} <music21.stream.Measure 12 offset=22.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.layout.StaffLayout distance None, staffNumber 1, staffSize None, staffLines None>
#         {0.0} <music21.harmony.ChordSymbol A7>
#         {0.0} <music21.note.Rest 16th>
#         {0.25} <music21.note.Note A>
#         {0.5} <music21.note.Note C#>
#         {0.75} <music21.note.Note E>
#         {1.0} <music21.note.Note G>
#         {1.25} <music21.note.Note A>
#         {1.5} <music21.note.Note B->
#         {1.75} <music21.note.Note G>
#     {24.0} <music21.stream.Measure 13 offset=24.0>
#         {0.0} <music21.harmony.ChordSymbol Dm>
#         {0.0} <music21.note.Note A>
#         {0.25} <music21.note.Note A>
#         {0.5} <music21.note.Note D>
#         {0.75} <music21.note.Note A>
#         {1.0} <music21.note.Note F>
#         {1.25} <music21.note.Note E>
#         {1.5} <music21.note.Note D>
#     {26.0} <music21.stream.Measure 14 offset=26.0>
#         {0.0} <music21.note.Rest 16th>
#         {0.25} <music21.harmony.ChordSymbol Dm7>
#         {0.25} <music21.note.Note A>
#         {0.5} <music21.note.Note D>
#         {0.75} <music21.note.Note E>
#         {1.0} <music21.note.Note F>
#         {1.25} <music21.note.Note G>
#         {1.5} <music21.note.Note A>
#         {1.75} <music21.note.Note F>
#     {28.0} <music21.stream.Measure 15 offset=28.0>
#         {0.0} <music21.harmony.ChordSymbol Gm7>
#         {0.0} <music21.note.Note G>
#         {0.25} <music21.note.Note G>
#         {0.5} <music21.note.Note B->
#         {0.75} <music21.note.Note G>
#         {1.0} <music21.note.Note E>
#         {1.25} <music21.note.Note D>
#         {1.5} <music21.note.Note C#>
#     {30.0} <music21.stream.Measure 16 offset=30.0>
#         {0.0} <music21.harmony.ChordSymbol A7>
#         {0.0} <music21.note.Rest 16th>
#         {0.25} <music21.note.Note A>
#         {0.5} <music21.note.Note C#>
#         {0.75} <music21.note.Note E>
#         {1.0} <music21.note.Note G>
#         {1.25} <music21.note.Note G->
#         {1.5} <music21.note.Note F>
#         {1.75} <music21.note.Note E>
#     {32.0} <music21.stream.Measure 17 offset=32.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.layout.StaffLayout distance None, staffNumber 1, staffSize None, staffLines None>
#         {0.0} <music21.bar.Barline type=regular>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {0.25} <music21.note.Note A>
#             {0.75} <music21.note.Note D>
#             {1.0} <music21.note.Rest 16th>
#             {1.25} <music21.note.Note E>
#             {1.5} <music21.note.Note F>
#         {0.0} <music21.stream.Voice 2>
#             {0.0} <music21.note.Note D>
#             {0.25} <music21.note.Note A>
#             {0.75} <music21.note.Note D>
#             {1.0} <music21.note.Rest 16th>
#             {1.25} <music21.note.Note A>
#             {1.5} <music21.note.Note D>
#         {0.25} <music21.harmony.ChordSymbol Dm>
#         {2.0} <music21.bar.Repeat direction=end>
#     {34.0} <music21.stream.Measure 18 offset=34.0>
#         {0.0} <music21.bar.Barline type=regular>
#         {0.0} <music21.note.Note D>
#         {1.0} <music21.harmony.ChordSymbol Dm>
#         {1.0} <music21.note.Note C>
#         {1.25} <music21.harmony.ChordSymbol C7>
#         {1.25} <music21.note.Note C>
#         {1.5} <music21.note.Note F>
#         {1.75} <music21.note.Note A>
#         {2.0} <music21.bar.Barline type=regular>
#     {36.0} <music21.stream.Measure 19 offset=36.0>
#         {0.0} <music21.expressions.RehearsalMark 'B'>
#         {0.0} <music21.bar.Repeat direction=start>
#         {0.0} <music21.note.Note C>
#         {0.5} <music21.harmony.ChordSymbol F>
#         {0.5} <music21.note.Note A>
#         {1.0} <music21.note.Note D>
#         {1.5} <music21.note.Note C>
#     {38.0} <music21.stream.Measure 20 offset=38.0>
#         {0.0} <music21.harmony.ChordSymbol C7>
#         {0.0} <music21.note.Note C>
#         {0.25} <music21.note.Note B->
#         {0.5} <music21.note.Note G>
#         {0.75} <music21.note.Note E>
#         {1.0} <music21.note.Note C>
#         {1.25} <music21.note.Note E>
#         {1.5} <music21.note.Note G>
#         {1.75} <music21.note.Note B->
#     {40.0} <music21.stream.Measure 21 offset=40.0>
#         {0.0} <music21.harmony.ChordSymbol C7>
#         {0.0} <music21.note.Note D>
#         {0.5} <music21.note.Note B->
#         {1.0} <music21.note.Note E>
#         {1.5} <music21.note.Note D>
#     {42.0} <music21.stream.Measure 22 offset=42.0>
#         {0.0} <music21.harmony.ChordSymbol F>
#         {0.0} <music21.note.Note D>
#         {0.25} <music21.note.Note C>
#         {0.5} <music21.note.Note A>
#         {0.75} <music21.note.Note F>
#         {1.0} <music21.note.Note C>
#         {1.25} <music21.note.Note F>
#         {1.5} <music21.note.Note A>
#         {1.75} <music21.note.Note C>
#     {44.0} <music21.stream.Measure 23 offset=44.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.layout.StaffLayout distance None, staffNumber 1, staffSize None, staffLines None>
#         {0.0} <music21.harmony.ChordSymbol F7>
#         {0.0} <music21.note.Note F>
#         {0.25} <music21.note.Note A>
#         {0.5} <music21.note.Note C>
#         {0.75} <music21.note.Note F>
#         {1.0} <music21.harmony.ChordSymbol E7>
#         {1.0} <music21.note.Note E>
#         {1.25} <music21.note.Note G#>
#         {1.5} <music21.note.Note B>
#         {1.75} <music21.note.Note E>
#     {46.0} <music21.stream.Measure 24 offset=46.0>
#         {0.0} <music21.harmony.ChordSymbol E-7>
#         {0.0} <music21.note.Note E->
#         {0.25} <music21.note.Note G>
#         {0.5} <music21.note.Note B->
#         {0.75} <music21.repeat.Coda 'Coda'>
#         {0.75} <music21.note.Note E->
#         {1.0} <music21.harmony.ChordSymbol D7>
#         {1.0} <music21.note.Note D>
#         {1.25} <music21.note.Note F#>
#         {1.5} <music21.note.Note A>
#         {1.75} <music21.note.Note D>
#         {127.0} <music21.repeat.Coda 'Coda'>
#         {127.0} <music21.bar.Barline type=double>
#     {173.0} <music21.stream.Measure 25 offset=173.0>
#         {0.0} <music21.harmony.ChordSymbol D-7>
#         {0.0} <music21.note.Note D->
#         {0.25} <music21.note.Note F>
#         {0.5} <music21.note.Note A->
#         {0.75} <music21.note.Note D->
#         {1.0} <music21.harmony.ChordSymbol C7>
#         {1.0} <music21.note.Note C>
#         {1.25} <music21.note.Note B->
#         {1.5} <music21.note.Note A>
#         {1.75} <music21.note.Note G>
#         {2.0} <music21.bar.Barline type=double>
#     {175.0} <music21.stream.Measure 26 offset=175.0>
#         {0.0} <music21.bar.Barline type=regular>
#         {0.0} <music21.harmony.ChordSymbol F>
#         {0.0} <music21.note.Note F>
#         {1.0} <music21.note.Rest 16th>
#         {1.25} <music21.note.Note C>
#         {1.5} <music21.note.Note F>
#         {1.75} <music21.note.Note A>
#         {2.0} <music21.bar.Repeat direction=end>
#     {177.0} <music21.stream.Measure 27 offset=177.0>
#         {0.0} <music21.bar.Barline type=regular>
#         {0.0} <music21.harmony.ChordSymbol F>
#         {0.0} <music21.note.Note F>
#         {0.25} <music21.note.Note F#>
#         {0.5} <music21.note.Note G>
#         {0.75} <music21.note.Note G#>
#         {1.0} <music21.harmony.ChordSymbol A7>
#         {1.0} <music21.note.Note A>
#         {2.0} <music21.bar.Barline type=regular>
#     {179.0} <music21.stream.Measure 28 offset=179.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.layout.StaffLayout distance None, staffNumber 1, staffSize None, staffLines None>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest 16th>
#             {0.25} <music21.note.Note A>
#             {0.75} <music21.note.Note D>
#             {1.0} <music21.note.Rest 16th>
#             {1.25} <music21.note.Note E>
#             {1.5} <music21.note.Note F>
#         {0.0} <music21.stream.Voice 2>
#             {0.0} <music21.note.Rest 16th>
#             {0.25} <music21.note.Note A>
#             {0.75} <music21.note.Note D>
#             {1.0} <music21.note.Rest 16th>
#             {1.25} <music21.note.Note A>
#             {1.5} <music21.note.Note D>
#         {0.25} <music21.harmony.ChordSymbol Dm>
#         {2.0} <music21.repeat.Segno 'Segno'>
#         {2.0} <music21.bar.Barline type=double>
#     {181.0} <music21.stream.Measure 29 offset=181.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.harmony.ChordSymbol D-7>
#         {0.0} <music21.note.Note D->
#         {0.25} <music21.note.Note F>
#         {0.5} <music21.note.Note A->
#         {0.75} <music21.note.Note D->
#         {1.0} <music21.harmony.ChordSymbol C7>
#         {1.0} <music21.note.Note C>
#         {1.25} <music21.note.Note E>
#         {1.5} <music21.note.Note G>
#         {1.75} <music21.note.Note C>
#     {183.0} <music21.stream.Measure 30 offset=183.0>
#         {0.0} <music21.harmony.ChordSymbol B7>
#         {0.0} <music21.note.Note B>
#         {0.25} <music21.note.Note D#>
#         {0.5} <music21.note.Note F#>
#         {0.75} <music21.note.Note B>
#         {1.0} <music21.harmony.ChordSymbol B-7>
#         {1.0} <music21.note.Note B->
#         {1.25} <music21.note.Note D>
#         {1.5} <music21.note.Note F>
#         {1.75} <music21.note.Note B->
#     {185.0} <music21.stream.Measure 31 offset=185.0>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.layout.StaffLayout distance None, staffNumber 1, staffSize None, staffLines None>
#         {0.0} <music21.harmony.ChordSymbol A7>
#         {0.0} <music21.note.Note A>
#         {0.25} <music21.note.Note C#>
#         {0.5} <music21.note.Note E>
#         {0.75} <music21.note.Note A>
#         {1.0} <music21.harmony.ChordSymbol A-7>
#         {1.0} <music21.note.Note A->
#         {1.25} <music21.note.Note C>
#         {1.5} <music21.note.Note E->
#         {1.75} <music21.note.Note A->
#     {187.0} <music21.stream.Measure 32 offset=187.0>
#         {0.0} <music21.harmony.ChordSymbol G7>
#         {0.0} <music21.note.Note G>
#         {1.0} <music21.note.Note G>
#     {189.0} <music21.stream.Measure 33 offset=189.0>
#         {0.0} <music21.harmony.ChordSymbol G-7>
#         {0.0} <music21.note.Note G->
#         {1.0} <music21.note.Note G->
#     {191.0} <music21.stream.Measure 34 offset=191.0>
#         {0.0} <music21.harmony.ChordSymbol F>
#         {0.0} <music21.note.Note F>
#         {1.0} <music21.note.Note G>
#         {1.25} <music21.note.Note F>
#         {1.5} <music21.note.Note C>
#         {1.75} <music21.note.Note F>
#     {193.0} <music21.stream.Measure 35 offset=193.0>
#         {0.0} <music21.note.Note B->
#         {0.25} <music21.note.Note A>
#         {0.5} <music21.note.Note F>
#         {0.75} <music21.note.Note A>
#         {1.0} <music21.note.Note D>
#         {1.25} <music21.note.Note C>
#         {1.5} <music21.note.Note A>
#         {1.75} <music21.note.Note C>
#     {195.0} <music21.stream.Measure 36 offset=195.0>
#         {0.0} <music21.harmony.ChordSymbol F>
#         {0.0} <music21.note.Note F>
#         {1.0} <music21.note.Rest quarter>
#         {2.0} <music21.bar.Barline type=final>
# {0.0} <music21.layout.ScoreLayout>
# Titre :  São João de Sapoti
# Repeats :  {1: [(17, 17), (18, 18)], 2: [(26, 26), (27, 27)]}
# Marques:  {'Segno': [1, 28], 'Coda': [24, 24], 'Start': [2, 19], 'End': [17, 26], 'Key': [1]}
# keys:  [<music21.key.Key of F major>]
# time signature:  2/4
# marques de repet : [("<music21.expressions.RehearsalMark 'A'>", 2), ("<music21.expressions.RehearsalMark 'B'>", 19)]
# Mesure 1:
# Expression: [('Baião', 0.75)]
# Notes: [('rest', 'quarter'), ('rest', '16th'), ('A4', '16th'), ('D5', '16th'), ('E5', '16th')]
# -----
# Mesure 2:
# Accord: [('Dm7', 0.5)]
# Notes: [('F5', '16th'), ('E5', '16th'), ('D5', '16th'), ('C5', '16th'), ('B-4', '16th'), ('A4', '16th'), ('G4', '16th'), ('A4', '16th')]
# -----
# Mesure 3:
# Accord: [('Gm7', 2.0)]
# Notes: [('B-4', '16th'), ('B-4', '16th'), ('D5', '16th'), ('B-4', '16th'), ('G4', '16th'), ('F4', '16th'), ('E4', 'eighth')]
# -----
# Mesure 4:
# Accord: [('A7', 1.75)]
# Notes: [('rest', '16th'), ('A3', '16th'), ('C#4', '16th'), ('E4', '16th'), ('G4', '16th'), ('A4', '16th'), ('B-4', '16th'), ('G4', '16th')]
# -----
# Mesure 5:
# Accord: [('Dm', 2.0)]
# Notes: [('A4', '16th'), ('A4', '16th'), ('D5', '16th'), ('A4', '16th'), ('F4', '16th'), ('E4', '16th'), ('D4', 'eighth')]
# -----
# Mesure 6:
# Accord: [('Dm7', 1.75)]
# Notes: [('rest', '16th'), ('A3', '16th'), ('D4', '16th'), ('E4', '16th'), ('F4', '16th'), ('G4', '16th'), ('A4', '16th'), ('F4', '16th')]
# -----
# Mesure 7:
# Accord: [('Gm7', 2.0)]
# Notes: [('G4', '16th'), ('G4', '16th'), ('B-4', '16th'), ('G4', '16th'), ('E4', '16th'), ('D4', '16th'), ('C#4', 'eighth')]
# -----
# Mesure 8:
# Accord: [('A7', 1.75)]
# Notes: [('rest', '16th'), ('A3', '16th'), ('C#4', '16th'), ('E4', '16th'), ('G4', '16th'), ('G-4', '16th'), ('F4', '16th'), ('E4', '16th')]
# -----
# Mesure 9:
# Accord: [('Dm', 2.5)]
# Notes: [('D4', '16th'), ('D4', '16th'), ('F4', '16th'), ('A4', '16th'), ('D5', '16th'), ('F4', '16th'), ('A4', '16th'), ('D5', '16th')]
# -----
# Mesure 10:
# Accord: [('Dm7', 2.5)]
# Notes: [('F5', '16th'), ('E5', '16th'), ('D5', '16th'), ('C5', '16th'), ('B-4', '16th'), ('A4', '16th'), ('G4', '16th'), ('A4', '16th')]
# -----
# Mesure 11:
# Accord: [('Gm7', 2.0)]
# Notes: [('B-4', '16th'), ('B-4', '16th'), ('D5', '16th'), ('B-4', '16th'), ('G4', '16th'), ('F4', '16th'), ('E4', 'eighth')]
# -----
# Mesure 12:
# Accord: [('A7', 1.75)]
# Notes: [('rest', '16th'), ('A3', '16th'), ('C#4', '16th'), ('E4', '16th'), ('G4', '16th'), ('A4', '16th'), ('B-4', '16th'), ('G4', '16th')]
# -----
# Mesure 13:
# Accord: [('Dm', 2.0)]
# Notes: [('A4', '16th'), ('A4', '16th'), ('D5', '16th'), ('A4', '16th'), ('F4', '16th'), ('E4', '16th'), ('D4', 'eighth')]
# -----
# Mesure 14:
# Accord: [('Dm7', 1.75)]
# Notes: [('rest', '16th'), ('A3', '16th'), ('D4', '16th'), ('E4', '16th'), ('F4', '16th'), ('G4', '16th'), ('A4', '16th'), ('F4', '16th')]
# -----
# Mesure 15:
# Accord: [('Gm7', 2.0)]
# Notes: [('G4', '16th'), ('G4', '16th'), ('B-4', '16th'), ('G4', '16th'), ('E4', '16th'), ('D4', '16th'), ('C#4', 'eighth')]
# -----
# Mesure 16:
# Accord: [('A7', 1.75)]
# Notes: [('rest', '16th'), ('A3', '16th'), ('C#4', '16th'), ('E4', '16th'), ('G4', '16th'), ('G-4', '16th'), ('F4', '16th'), ('E4', '16th')]
# -----
# Mesure 17:
# Accord: [('Dm', 0.5)]
# Notes: [('D4', '16th'), ('A4', 'eighth'), ('D5', '16th'), ('rest', '16th'), ('E5', '16th'), ('F5', 'eighth')]
# -----
# Mesure 18:
# Accord: [('Dm', 1.0), ('C7', 0.25)]
# Notes: [('D4', 'quarter'), ('C4', '16th'), ('C4', '16th'), ('F4', '16th'), ('A4', '16th')]
# -----
# Mesure 19:
# Accord: [('F', 0.5)]
# Notes: [('C5', 'eighth'), ('A4', 'eighth'), ('D5', 'eighth'), ('C5', 'eighth')]
# -----
# Mesure 20:
# Accord: [('C7', 2.0)]
# Notes: [('C5', '16th'), ('B-4', '16th'), ('G4', '16th'), ('E4', '16th'), ('C4', '16th'), ('E4', '16th'), ('G4', '16th'), ('B-4', '16th')]
# -----
# Mesure 21:
# Accord: [('C7', 2.0)]
# Notes: [('D5', 'eighth'), ('B-4', 'eighth'), ('E5', 'eighth'), ('D5', 'eighth')]
# -----
# Mesure 22:
# Accord: [('F', 2.0)]
# Notes: [('D5', '16th'), ('C5', '16th'), ('A4', '16th'), ('F4', '16th'), ('C4', '16th'), ('F4', '16th'), ('A4', '16th'), ('C5', '16th')]
# -----
# Mesure 23:
# Accord: [('F7', 1.0), ('E7', 1.0)]
# Notes: [('F5', '16th'), ('A4', '16th'), ('C5', '16th'), ('F5', '16th'), ('E5', '16th'), ('G#4', '16th'), ('B4', '16th'), ('E5', '16th')]
# -----
# Mesure 24:
# Accord: [('E-7', 1.0), ('D7', 1.0)]
# Notes: [('E-5', '16th'), ('G4', '16th'), ('B-4', '16th'), ('E-5', '16th'), ('D5', '16th'), ('F#4', '16th'), ('A4', '16th'), ('D5', '16th')]
# -----
# Mesure 25:
# Accord: [('D-7', 1.0), ('C7', 1.0)]
# Notes: [('D-5', '16th'), ('F4', '16th'), ('A-4', '16th'), ('D-5', '16th'), ('C5', '16th'), ('B-4', '16th'), ('A4', '16th'), ('G4', '16th')]
# -----
# Mesure 26:
# Accord: [('F', 1.75)]
# Notes: [('F4', 'quarter'), ('rest', '16th'), ('C4', '16th'), ('F4', '16th'), ('A4', '16th')]
# -----
# Mesure 27:
# Accord: [('F', 1.0), ('A7', 1.0)]
# Notes: [('F4', '16th'), ('F#4', '16th'), ('G4', '16th'), ('G#4', '16th'), ('A4', 'quarter')]
# -----
# Mesure 28:
# Accord: [('Dm', 3.0)]
# Notes: [('rest', '16th'), ('A4', 'eighth'), ('D5', '16th'), ('rest', '16th'), ('E5', '16th'), ('F5', 'eighth')]
# -----
# Mesure 29:
# Accord: [('D-7', 1.0), ('C7', 1.0)]
# Notes: [('D-5', '16th'), ('F4', '16th'), ('A-4', '16th'), ('D-5', '16th'), ('C5', '16th'), ('E4', '16th'), ('G4', '16th'), ('C5', '16th')]
# -----
# Mesure 30:
# Accord: [('B7', 1.0), ('B-7', 1.0)]
# Notes: [('B4', '16th'), ('D#4', '16th'), ('F#4', '16th'), ('B4', '16th'), ('B-4', '16th'), ('D4', '16th'), ('F4', '16th'), ('B-4', '16th')]
# -----
# Mesure 31:
# Accord: [('A7', 1.0), ('A-7', 1.0)]
# Notes: [('A4', '16th'), ('C#4', '16th'), ('E4', '16th'), ('A4', '16th'), ('A-4', '16th'), ('C4', '16th'), ('E-4', '16th'), ('A-4', '16th')]
# -----
# Mesure 32:
# Accord: [('G7', 2.0)]
# Notes: [('G4', 'quarter'), ('G4', 'quarter')]
# -----
# Mesure 33:
# Accord: [('G-7', 2.0)]
# Notes: [('G-4', 'quarter'), ('G-4', 'quarter')]
# -----
# Mesure 34:
# Accord: [('F', 2.0)]
# Notes: [('F4', 'quarter'), ('G4', '16th'), ('F4', '16th'), ('C4', '16th'), ('F4', '16th')]
# -----
# Mesure 35:
# Notes: [('B-4', '16th'), ('A4', '16th'), ('F4', '16th'), ('A4', '16th'), ('D5', '16th'), ('C5', '16th'), ('A4', '16th'), ('C5', '16th')]
# -----
# Mesure 36:
# Accord: [('F', 1.0)]
# Notes: [('F5', 'quarter'), ('rest', 'quarter')]
# -----
